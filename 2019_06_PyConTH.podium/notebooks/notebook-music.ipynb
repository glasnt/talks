# %% [markdown]
# ## Music in a Notebook
#
# Requires:
#  * `brew install musescore`
#  * `pip install music21`

# %%
from music21 import *
converter.parse("tinynotation: 4/4 f4. g8~ g2 c4 g4. a8~ a4 c'16 b-16 a8 f4. g8~ g2 c4~ c. r4").show()
